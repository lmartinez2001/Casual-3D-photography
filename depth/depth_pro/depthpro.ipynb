# %%
import os
import depth_pro

# %%
model, transform = depth_pro.create_model_and_transforms()
model.eval()
print("Model loaded")
# Out:
# Model loaded

# %%
root = "../Volumes/prn1_smb_computational_photo_001/projects/3DPhoto/Data/intermediate_data/creepy-attic/sparse"
images_root = os.path.join(root, "undistorted")

image, _, f_px = depth_pro.load_rgb(os.path.join(images_root, "000.jpg"))
image = transform(image)

# %%
prediction = model.infer(image, f_px=f_px)
depth = prediction["depth"]  # Depth in [m].
focallength_px = prediction["focallength_px"]  # Focal length in pixels.

# %%
import matplotlib.pyplot as plt

plt.imshow(prediction["depth"], cmap="magma")
